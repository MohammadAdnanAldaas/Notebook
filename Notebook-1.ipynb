-- %%
CREATE TABLE leagues (leaguecode varchar(3) NOT NULL, leaguename varchar(50) NOT NULL)
CREATE TABLE teams (Teamname varchar(50) NOT NULL,  Teamfullname varchar(50) NOT NULL, NationalityCode varchar(10) NOT NULL, EngineSupplier varchar(50) NOT NULL )
CREATE TABLE Drivers (DriverName varchar(50) NOT NULL, DateOfBirth date NOT NULL, DriverCode varchar(3) NOT NULL, City varchar(50) NOT NULL, NationalityCode varchar(10) NOT NULL)
CREATE TABLE Circuits (Circuitcode varchar(50) NOT NULL, Grandprixname varchar (50) NOT NULL, Nationalitycode varchar(10) NOT NULL, CircuitLocation varchar(50) NOT NULL, CircuitRegion varchar(50) NOT NULL )
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.004
